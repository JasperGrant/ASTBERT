# %% [markdown]
# # Extract all methods from the files

# %%
from extract_method import extract_method_from_folder

extract_method_from_folder("raw_repo")
# Out:
# raw_repo\apache_jmeter\config\license.header.java
# parse successfully
# raw_repo\apache_jmeter\src\bshclient\src\main\java\org\apache\jmeter\util\BeanShellClient.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\BeanShellAssertion.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\BSFAssertion.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\BSFAssertionBeanInfo.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\CompareAssertion.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\CompareAssertionBeanInfo.java
# parse successfully
# raw_repo\apache_jmeter\src\components\src\main\java\org\apache\jmeter\assertions\DurationAssertion.java
# parse successfully
# ...

# %%
from extract_method import extract_method_from_file

extract_method_from_file("class_for_test/BeanShellClient.java")
# Out:
# parse successfully

# %%
from extract_method import extract_method_from_file

extract_method_from_file("class_for_test/CLOption.java")
# Out:
# parse successfully
